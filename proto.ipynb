# %%
stuff = """
Private Third Class 	2000 	10,000 	
Private Second Class 	3000 	15,000 	
Private First Class 	4000 	20,000 	
Corporal 	5000 	25,000 	
Sergeant Third Class 	6000 	30,000 	Must complete Company Hunting Log Rank 1
Sergeant Second Class 	7000 	35,000 	Unlocks Expert Delivery
Sergeant First Class 	8000 	40,000 	
Chief Sergeant 	9000 	45,000 	Must complete Shadows Uncast
Second Lieutenant 	10,000 	50,000 	Must complete Gilding the Bilious
First Lieutenant 	0 	80,000 	Adventurer Squadrons Rank 3 by completing Flagged Mission: Crystal Recovery
Captain """

# %%
[z[:-1] for z in [x.split("\t")[0] for x in stuff.split("\n")][1:]]
# Out:
# ['Private Third Class',
#  'Private Second Class',
#  'Private First Class',
#  'Corporal',
#  'Sergeant Third Class',
#  'Sergeant Second Class',
#  'Sergeant First Class',
#  'Chief Sergeant',
#  'Second Lieutenant',
#  'First Lieutenant',
#  'Captain']

# %%
import pandas as pd

# %%
df = pd.read_csv("Item.csv",skiprows=[0,2])

# %%
df.columns
# Out:
# Index(['#', 'Singular', 'Adjective', 'Plural', 'PossessivePronoun',
#        'StartsWithVowel', 'Unnamed: 6', 'Pronoun', 'Article', 'Description',
#        'Name', 'Icon', 'Level{Item}', 'Rarity', 'FilterGroup',
#        'AdditionalData', 'ItemUICategory', 'ItemSearchCategory',
#        'EquipSlotCategory', 'ItemSortCategory', 'Unnamed: 20', 'StackSize',
#        'IsUnique', 'IsUntradable', 'IsIndisposable', 'Lot', 'Price{Mid}',
#        'Price{Low}', 'CanBeHq', 'DyeCount', 'IsCrestWorthy', 'ItemAction',
#        'CastTime<s>', 'Cooldown<s>', 'ClassJob{Repair}', 'Item{Repair}',
#        'Item{Glamour}', 'Desynth', 'IsCollectable', 'AlwaysCollectable',
#        'AetherialReduce', 'Level{Equip}', 'RequiredPvpRank',
#        'EquipRestriction', 'ClassJobCategory', 'GrandCompany', 'ItemSeries',
#        'BaseParamModifier', 'Model{Main}', 'Model{Sub}', 'ClassJob{Use}',
#        'Unnamed: 51', 'Damage{Phys}', 'Damage{Mag}', 'Delay<ms>',
#        'Unnamed: 55', 'BlockRate', 'Block', 'Defense{Phys}', 'Defense{Mag}',
#        'BaseParam[0]', 'BaseParamValue[0]', 'BaseParam[1]',
#        'BaseParamValue[1]', 'BaseParam[2]', 'BaseParamValue[2]',
#        'BaseParam[3]', 'BaseParamValue[3]', 'BaseParam[4]',
#        'BaseParamValue[4]', 'BaseParam[5]', 'BaseParamValue[5]',
#        'ItemSpecialBonus', 'ItemSpecialBonus{Param}', 'BaseParam{Special}[0]',
#        'BaseParamValue{Special}[0]', 'BaseParam{Special}[1]',
#        'BaseParamValue{Special}[1]', 'BaseParam{Special}[2]',
#        'BaseParamValue{Special}[2]', 'BaseParam{Special}[3]',
#        'BaseParamValue{Special}[3]', 'BaseParam{Special}[4]',
#        'BaseParamValue{Special}[4]', 'BaseParam{Special}[5]',
#        'BaseParamValue{Special}[5]', 'MaterializeType', 'MateriaSlotCount',
#        'IsAdvancedMeldingPermitted', 'IsPvP', 'SubStatCategory',
#        'IsGlamourous'],
#       dtype='object')

# %%
df = df.dropna()
print(df[df["Name"].str.match("Storm Desk")])
rpow = df[df["Name"].str.match("Storm Desk")]
for x in df.columns:
    print(rpow[x])
# Out:
#          #    Singular  Adjective       Plural  PossessivePronoun  \
# 6538  6538  storm desk          0  storm desks                  0
#
#       StartsWithVowel  Unnamed: 6  Pronoun  Article  \
# 6538                0           1        0        0
#
#                                      Description  ... BaseParam{Special}[4]  \
# 6538  An officer's desk issued by the Maelstrom.  ...                     0
#
#       BaseParamValue{Special}[4]  BaseParam{Special}[5]  \
# 6538                           0                      0
#
#       BaseParamValue{Special}[5]  MaterializeType  MateriaSlotCount  \
# 6538                           0                0                 0
#
#       IsAdvancedMeldingPermitted  IsPvP  SubStatCategory  IsGlamourous
# 6538                       False  False                0         False
#
# [1 rows x 92 columns]
# 6538    6538
# Name: #, dtype: int64
# 6538    storm desk
# Name: Singular, dtype: object
# 6538    0
# Name: Adjective, dtype: int64
# 6538    storm desks
# Name: Plural, dtype: object
# 6538    0
# Name: PossessivePronoun, dtype: int64
# 6538    0
# Name: StartsWithVowel, dtype: int64
# 6538    1
# Name: Unnamed: 6, dtype: int64
# 6538    0
# Name: Pronoun, dtype: int64
# 6538    0
# Name: Article, dtype: int64
# 6538    An officer's desk issued by the Maelstrom.
# Name: Description, dtype: object
# 6538    Storm Desk
# Name: Name, dtype: object
# 6538    51603
# Name: Icon, dtype: int64
# 6538    40
# Name: Level{Item}, dtype: int64
# 6538    1
# Name: Rarity, dtype: int64
# 6538    14
# Name: FilterGroup, dtype: int64
# 6538    196727
# Name: AdditionalData, dtype: int64
# 6538    77
# Name: ItemUICategory, dtype: int64
# 6538    69
# Name: ItemSearchCategory, dtype: int64
# 6538    0
# Name: EquipSlotCategory, dtype: int64
# 6538    50
# Name: ItemSortCategory, dtype: int64
# 6538    2200
# Name: Unnamed: 20, dtype: int64
# 6538    1
# Name: StackSize, dtype: int64
# 6538    False
# Name: IsUnique, dtype: bool
# 6538    False
# Name: IsUntradable, dtype: bool
# 6538    False
# Name: IsIndisposable, dtype: bool
# 6538    False
# Name: Lot, dtype: bool
# 6538    16200
# Name: Price{Mid}, dtype: int64
# 6538    60
# Name: Price{Low}, dtype: int64
# 6538    False
# Name: CanBeHq, dtype: bool
# 6538    0
# Name: DyeCount, dtype: int64
# 6538    False
# Name: IsCrestWorthy, dtype: bool
# 6538    0
# Name: ItemAction, dtype: int64
# 6538    2
# Name: CastTime<s>, dtype: int64
# 6538    0
# Name: Cooldown<s>, dtype: int64
# 6538    8
# Name: ClassJob{Repair}, dtype: int64
# 6538    0
# Name: Item{Repair}, dtype: int64
# 6538    0
# Name: Item{Glamour}, dtype: int64
# 6538    5636
# Name: Desynth, dtype: int64
# 6538    False
# Name: IsCollectable, dtype: bool
# 6538    False
# Name: AlwaysCollectable, dtype: bool
# 6538    0
# Name: AetherialReduce, dtype: int64
# 6538    1
# Name: Level{Equip}, dtype: int64
# 6538    0
# Name: RequiredPvpRank, dtype: int64
# 6538    0
# Name: EquipRestriction, dtype: int64
# 6538    0
# Name: ClassJobCategory, dtype: int64
# 6538    0
# Name: GrandCompany, dtype: int64
# 6538    0
# Name: ItemSeries, dtype: int64
# 6538    0
# Name: BaseParamModifier, dtype: int64
# 6538    0, 0, 0, 0
# Name: Model{Main}, dtype: object
# 6538    0, 0, 0, 0
# Name: Model{Sub}, dtype: object
# 6538    0
# Name: ClassJob{Use}, dtype: int64
# 6538    0
# Name: Unnamed: 51, dtype: int64
# 6538    0
# Name: Damage{Phys}, dtype: int64
# 6538    0
# Name: Damage{Mag}, dtype: int64
# 6538    0
# Name: Delay<ms>, dtype: int64
# 6538    0
# Name: Unnamed: 55, dtype: int64
# 6538    0
# Name: BlockRate, dtype: int64
# 6538    0
# Name: Block, dtype: int64
# 6538    0
# Name: Defense{Phys}, dtype: int64
# 6538    0
# Name: Defense{Mag}, dtype: int64
# 6538    0
# Name: BaseParam[0], dtype: int64
# 6538    0
# Name: BaseParamValue[0], dtype: int64
# 6538    0
# Name: BaseParam[1], dtype: int64
# 6538    0
# Name: BaseParamValue[1], dtype: int64
# 6538    0
# Name: BaseParam[2], dtype: int64
# 6538    0
# Name: BaseParamValue[2], dtype: int64
# 6538    0
# Name: BaseParam[3], dtype: int64
# 6538    0
# Name: BaseParamValue[3], dtype: int64
# 6538    0
# Name: BaseParam[4], dtype: int64
# 6538    0
# Name: BaseParamValue[4], dtype: int64
# 6538    0
# Name: BaseParam[5], dtype: int64
# 6538    0
# Name: BaseParamValue[5], dtype: int64
# 6538    0
# Name: ItemSpecialBonus, dtype: int64
# 6538    0
# Name: ItemSpecialBonus{Param}, dtype: int64
# 6538    0
# Name: BaseParam{Special}[0], dtype: int64
# 6538    0
# Name: BaseParamValue{Special}[0], dtype: int64
# 6538    0
# Name: BaseParam{Special}[1], dtype: int64
# 6538    0
# Name: BaseParamValue{Special}[1], dtype: int64
# 6538    0
# Name: BaseParam{Special}[2], dtype: int64
# 6538    0
# Name: BaseParamValue{Special}[2], dtype: int64
# 6538    0
# Name: BaseParam{Special}[3], dtype: int64
# 6538    0
# Name: BaseParamValue{Special}[3], dtype: int64
# 6538    0
# Name: BaseParam{Special}[4], dtype: int64
# 6538    0
# Name: BaseParamValue{Special}[4], dtype: int64
# 6538    0
# Name: BaseParam{Special}[5], dtype: int64
# 6538    0
# Name: BaseParamValue{Special}[5], dtype: int64
# 6538    0
# Name: MaterializeType, dtype: int64
# 6538    0
# Name: MateriaSlotCount, dtype: int64
# 6538    False
# Name: IsAdvancedMeldingPermitted, dtype: bool
# 6538    False
# Name: IsPvP, dtype: bool
# 6538    0
# Name: SubStatCategory, dtype: int64
# 6538    False
# Name: IsGlamourous, dtype: bool

# %%
df[df["Name"].str.match("Storm")]["ItemSortCategory"]
# Out:
# 20        3
# 3994      5
# 4027      5
# 5035     13
# 5799     11
# 5890     61
# 6017     55
# 6170     59
# 6470     50
# 6526     50
# 6538     50
# 6545     50
# 6553     50
# 6556     50
# 7133     50
# 7143     50
# 7713     14
# 8209     59
# 12746    13
# 12835    13
# 15134    50
# 15135    50
# 15136    50
# 17568    16
# 17571    16
# 17846    59
# 23178    16
# 24869    59
# 24877    59
# 24879    59
# 27497    13
# 33248    50
# 38612    50
# Name: ItemSortCategory, dtype: int64

# %%
df.head()
# Out:
#    #    Singular  Adjective       Plural  PossessivePronoun  StartsWithVowel  \
# 0  0         NaN          0          NaN                  0                0
# 1  1         gil          0          gil                  0                0
# 2  2  fire shard          0  fire shards                  0                0
# 3  3   ice shard          0   ice shards                  0                1
# 4  4  wind shard          0  wind shards                  0                0
#
#    Unnamed: 6  Pronoun  Article  \
# 0           1        0        0
# 1           1        0        0
# 2           1        0        0
# 3           1        0        0
# 4           1        0        0
#
#                                          Description  ...  \
# 0                                                NaN  ...
# 1                         Standard Eorzean currency.  ...
# 2  A tiny crystalline manifestation of aetheric f...  ...
# 3  A tiny crystalline manifestation of aetheric i...  ...
# 4  A tiny crystalline manifestation of aetheric w...  ...
#
#   BaseParam{Special}[4]  BaseParamValue{Special}[4]  BaseParam{Special}[5]  \
# 0                     0                           0                      0
# 1                     0                           0                      0
# 2                     0                           0                      0
# 3                     0                           0                      0
# 4                     0                           0                      0
#
#    BaseParamValue{Special}[5]  MaterializeType  MateriaSlotCount  \
# 0                           0                0                 0
# 1                           0                0                 0
# 2                           0                0                 0
# 3                           0                0                 0
# 4                           0                0                 0
#
#    IsAdvancedMeldingPermitted  IsPvP  SubStatCategory  IsGlamourous
# 0                       False  False                0         False
# 1                       False  False                0         False
# 2                       False  False                0         False
# 3                       False  False                0         False
# 4                       False  False                0         False
#
# [5 rows x 92 columns]

# %%
df.head().style.format(precision=2, na_rep='NaN', formatter="{:.2f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/io/formats/style.py:272, in Styler._repr_html_(self)
#     267 """
#     268 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     269 default if an object is returned at the end of a cell.
#     270 """
#     271 if get_option("styler.render.repr") == "html":
# --> 272     return self.to_html()
#     273 return None
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/io/formats/style.py:1178, in Styler.to_html(self, buf, table_uuid, table_attributes, sparse_index, sparse_columns, bold_headers, caption, max_rows, max_columns, encoding, doctype_html, exclude_styles, **kwargs)
#    1176 encoding = encoding or get_option("styler.render.encoding")
#    1177 # Build HTML string..
# -> 1178 html = obj._render_html(
#    1179     sparse_index=sparse_index,
#    1180     sparse_columns=sparse_columns,
#    1181     max_rows=max_rows,
#    1182     max_cols=max_columns,
#    1183     exclude_styles=exclude_styles,
#    1184     encoding=encoding,
#    1185     doctype_html=doctype_html,
#    1186     **kwargs,
#    1187 )
#    1189 return save_to_buffer(
#    1190     html, buf=buf, encoding=(encoding if buf is not None else None)
#    1191 )
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/io/formats/style_render.py:164, in StylerRenderer._render_html(self, sparse_index, sparse_columns, max_rows, max_cols, **kwargs)
#     162 self._compute()
#     163 # TODO: namespace all the pandas keys
# --> 164 d = self._translate(sparse_index, sparse_columns, max_rows, max_cols)
#     165 d.update(kwargs)
#     166 return self.template_html.render(
#     167     **d,
#     168     html_table_tpl=self.template_html_table,
#     169     html_style_tpl=self.template_html_style,
#     170 )
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/io/formats/style_render.py:279, in StylerRenderer._translate(self, sparse_index, sparse_cols, max_rows, max_cols, blank)
#     273 self.cellstyle_map: DefaultDict[tuple[CSSPair, ...], list[str]] = defaultdict(
#     274     list
#     275 )
#     276 self.cellstyle_map_index: DefaultDict[
#     277     tuple[CSSPair, ...], list[str]
#     278 ] = defaultdict(list)
# --> 279 body = self._translate_body(idx_lengths, max_rows, max_cols)
#     280 d.update({"body": body})
#     282 ctx_maps = {
#     283     "cellstyle": "cellstyle_map",
#     284     "cellstyle_index": "cellstyle_map_index",
#     285     "cellstyle_columns": "cellstyle_map_columns",
#     286 }  # add the cell_ids styles map to the render dictionary in right format
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/io/formats/style_render.py:566, in StylerRenderer._translate_body(self, idx_lengths, max_rows, max_cols)
#     564         body.append(trimmed_row)
#     565         break
# --> 566     body_row = self._generate_body_row(
#     567         (r, row_tup, rlabels), max_cols, idx_lengths
#     568     )
#     569     body.append(body_row)
#     570 return body
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/io/formats/style_render.py:733, in StylerRenderer._generate_body_row(self, iter, max_cols, idx_lengths)
#     721 if (r, c) in self.cell_context:
#     722     cls = " " + self.cell_context[r, c]
#     724 data_element = _element(
#     725     "td",
#     726     (
#     727         f"{self.css['data']} {self.css['row']}{r} "
#     728         f"{self.css['col']}{c}{cls}"
#     729     ),
#     730     value,
#     731     data_element_visible,
#     732     attributes="",
# --> 733     display_value=self._display_funcs[(r, c)](value),
#     734 )
#     736 if self.cell_ids:
#     737     data_element["id"] = f"{self.css['row']}{r}_{self.css['col']}{c}"
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/io/formats/style_render.py:1552, in _maybe_wrap_formatter.<locals>.<lambda>(x)
#    1550     return func_3
#    1551 else:
# -> 1552     return lambda x: na_rep if isna(x) else func_3(x)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/io/formats/style_render.py:1517, in _maybe_wrap_formatter.<locals>.<lambda>(x)
#    1515 # Get initial func from input string, input callable, or from default factory
#    1516 if isinstance(formatter, str):
# -> 1517     func_0 = lambda x: formatter.format(x)
#    1518 elif callable(formatter):
#    1519     func_0 = formatter
#
# ValueError: Unknown format code 'f' for object of type 'str'

# %%
df["GrandCompany"].value_counts()
# Out:
# 0    43854
# 3      183
# 2      182
# 1      182
# Name: GrandCompany, dtype: int64

# %%
#0 none 1 mael 2 adders 3 flames
#"\#", "name", 'StackSize', 'IsUnique', 'IsUntradable'

# %%
df[(df["GrandCompany"] == 1) & (df["IsUntradable"]!=True)]#["\#", "name", 'StackSize', 'IsUnique', 'IsUntradable']
# Out:
# Empty DataFrame
# Columns: [#, Singular, Adjective, Plural, PossessivePronoun, StartsWithVowel, Unnamed: 6, Pronoun, Article, Description, Name, Icon, Level{Item}, Rarity, FilterGroup, AdditionalData, ItemUICategory, ItemSearchCategory, EquipSlotCategory, ItemSortCategory, Unnamed: 20, StackSize, IsUnique, IsUntradable, IsIndisposable, Lot, Price{Mid}, Price{Low}, CanBeHq, DyeCount, IsCrestWorthy, ItemAction, CastTime<s>, Cooldown<s>, ClassJob{Repair}, Item{Repair}, Item{Glamour}, Desynth, IsCollectable, AlwaysCollectable, AetherialReduce, Level{Equip}, RequiredPvpRank, EquipRestriction, ClassJobCategory, GrandCompany, ItemSeries, BaseParamModifier, Model{Main}, Model{Sub}, ClassJob{Use}, Unnamed: 51, Damage{Phys}, Damage{Mag}, Delay<ms>, Unnamed: 55, BlockRate, Block, Defense{Phys}, Defense{Mag}, BaseParam[0], BaseParamValue[0], BaseParam[1], BaseParamValue[1], BaseParam[2], BaseParamValue[2], BaseParam[3], BaseParamValue[3], BaseParam[4], BaseParamValue[4], BaseParam[5], BaseParamValue[5], ItemSpecialBonus, ItemSpecialBonus{Param}, BaseParam{Special}[0], BaseParamValue{Special}[0], BaseParam{Special}[1], BaseParamValue{Special}[1], BaseParam{Special}[2], BaseParamValue{Special}[2], BaseParam{Special}[3], BaseParamValue{Special}[3], BaseParam{Special}[4], BaseParamValue{Special}[4], BaseParam{Special}[5], BaseParamValue{Special}[5], MaterializeType, MateriaSlotCount, IsAdvancedMeldingPermitted, IsPvP, SubStatCategory, IsGlamourous]
# Index: []
#
# [0 rows x 92 columns]

# %%
df[df["Name"]=="Glass Fiber"]
# Out:
#            #             Singular  Adjective                Plural  \
# 15649  15649  loop of glass fiber          0  loops of glass fiber
#
#        PossessivePronoun  StartsWithVowel  Unnamed: 6  Pronoun  Article  \
# 15649                  0                0           1        0        0
#
#                                              Description  ...  \
# 15649  Thinly spun glass remarkably resistant to high...  ...
#
#       BaseParam{Special}[4]  BaseParamValue{Special}[4]  \
# 15649                     0                           0
#
#        BaseParam{Special}[5]  BaseParamValue{Special}[5]  MaterializeType  \
# 15649                      0                           0                0
#
#        MateriaSlotCount  IsAdvancedMeldingPermitted  IsPvP  SubStatCategory  \
# 15649                 0                       False  False                0
#
#        IsGlamourous
# 15649         False
#
# [1 rows x 92 columns]

# %%
gcs = pd.read_csv("GCScripShopItem.csv", skiprows=[0,2,3])

# %%
gcs = gcs.dropna()
gcs[gcs["Name"].str.match("Flame")]
# Out:
#          #  Item  Required{GrandCompanyRank}  Cost{GCSeals}  SortKey  \
# 518  19.60  6019                           1            200       50
# 589  22.10  6527                           8           5050      200
# 590  22.11  6555                           8           6900      200
# 591  22.12  6540                           8           8300      200
# 592  22.13  6558                           8           6700      200
# 593  22.14  6547                           8           9070      200
# 596  22.17  6471                           8           6800      200
# 677  25.10  6172                           9          20000       90
# 681  25.50  7135                           9          10950       90
# 682  25.60  7145                           9          10950       90
#
#                          Name  StackSize IsUnique IsUntradable
# 518    Flame Chocobo Issuance        1.0     True         True
# 589       Flame Storage Bench        1.0    False        False
# 590             Flame Armoire        1.0    False        False
# 591                Flame Desk        1.0    False        False
# 592           Flame Strongbox        1.0    False        False
# 593         Flame Utility Cot        1.0    False        False
# 596  Flame Ceiling Fan & Lamp        1.0    False        False
# 677           Flame Hatchling        1.0     True         True
# 681       Flame Interior Wall        1.0    False        False
# 682            Flame Flooring        1.0    False        False

# %%
gcs[gcs["Name"].str.match("Coke")]
# Out:
#         #  Item  Required{GrandCompanyRank}  Cost{GCSeals}  SortKey  Name  \
# 778  30.3  5530                           9            200       40  Coke
# 825  33.3  5530                           9            200       40  Coke
# 872  36.3  5530                           9            200       40  Coke
#
#      StackSize IsUnique IsUntradable
# 778      999.0    False        False
# 825      999.0    False        False
# 872      999.0    False        False

# %%
gcs.head()
# Out:
#      #  Item  Required{GrandCompanyRank}  Cost{GCSeals}  SortKey
# 0  1.0  5594                           1             12       50
# 1  1.1  5595                           1             34       50
# 2  1.2  5596                           1             70       50
# 3  1.3  4564                           1            120       50
# 4  1.4  4566                           1            290       50

# %%
def maplink(df1,df2,keys):
    for key in keys:
        df1[key] = gcs["Item"].map(df.set_index("#")[key])

# %%
maplink(gcs,df, ["Name", 'StackSize', 'IsUnique', 'IsUntradable'])

# %%
gcs.columns[2]
# Out:
# 'Required{GrandCompanyRank}'

# %%
gcs=gcs.rename(columns={gcs.columns[2]:"RequiredGCRank","Cost{GCSeals}":"GCSealsCost"})

# %%
gcs
# Out:
#          #   Item  RequiredGCRank  GCSealsCost  SortKey  \
# 0     1.00   5594               1           12       50
# 1     1.10   5595               1           34       50
# 2     1.20   5596               1           70       50
# 3     1.30   4564               1          120       50
# 4     1.40   4566               1          290       50
# ..     ...    ...             ...          ...      ...
# 906  36.37  16933               9         4000       10
# 907  36.38   9356               9         2300       15
# 908  36.39  15649               9         7000       15
# 909  36.40   9357              11         2500       60
# 910  36.41      0               0            0        0
#
#                         Name  StackSize  IsUnique  IsUntradable
# 0        Grade 1 Dark Matter        999     False         False
# 1        Grade 2 Dark Matter        999     False         False
# 2        Grade 3 Dark Matter        999     False         False
# 3                   Antidote        999     False         False
# 4                 Echo Drops        999     False         False
# ..                       ...        ...       ...           ...
# 906                 Pneumite        999     False          True
# 907  Quick-hardening Sealant        999     False         False
# 908              Glass Fiber        999     False         False
# 909   Xelphatol Spring Water        999     False         False
# 910                      NaN          1     False         False
#
# [911 rows x 9 columns]

# %%
gcs["IsTradeable"] = gcs["IsUntradable"] ^ True

# %%
gcs[["Item","Name","RequiredGCRank","GCSealsCost","StackSize","IsUnique","IsTradeable"]].dropna()
# Out:
#       Item                     Name  RequiredGCRank  GCSealsCost  StackSize  \
# 0     5594      Grade 1 Dark Matter               1           12        999
# 1     5595      Grade 2 Dark Matter               1           34        999
# 2     5596      Grade 3 Dark Matter               1           70        999
# 3     4564                 Antidote               1          120        999
# 4     4566               Echo Drops               1          290        999
# ..     ...                      ...             ...          ...        ...
# 905  10119               Duck Bones               9          600        999
# 906  16933                 Pneumite               9         4000        999
# 907   9356  Quick-hardening Sealant               9         2300        999
# 908  15649              Glass Fiber               9         7000        999
# 909   9357   Xelphatol Spring Water              11         2500        999
#
#      IsUnique  IsTradeable
# 0       False         True
# 1       False         True
# 2       False         True
# 3       False         True
# 4       False         True
# ..        ...          ...
# 905     False        False
# 906     False        False
# 907     False         True
# 908     False         True
# 909     False         True
#
# [857 rows x 7 columns]

# %%
import pandas as pd

item_df = pd.read_csv("Item.csv",skiprows=[0,2])
gc_item_df = pd.read_csv("GCScripShopItem.csv", skiprows=[0,2,3])
gc_cat_df = pd.read_csv("GCScripShopCategory.csv", skiprows=[0,2])
gc_item_df["#"] = gc_item_df["#"].astype(int)
def maplink(df1,df2,keys,key1="Item"):
    for key in keys:
        df1[key] = df1[key1].map(df2.set_index("#")[key])

maplink(gc_item_df, item_df, ["Name", 'StackSize', 'IsUnique', 'IsUntradable'])
print(gc_item_df.columns)
maplink(gc_item_df,gc_cat_df, ["GrandCompany"],key1="#")
#TODO: its the dupe entries for each GC thats causing problems
# gc_item_df["GrandCompany"] = gc_item_df["#"].astype(int).map(gc_cat_df.set_index("#")["GrandCompany"])
# print(gc_item_df.columns)
gc_item_df=gc_item_df.rename(columns={gc_item_df.columns[2]:"RequiredGCRank","Cost{GCSeals}":"GCSealsCost"})
print(len(gc_item_df))
print(gc_item_df["GrandCompany"].value_counts())
gc_item_df.loc[gc_item_df["Item"].duplicated(keep = False),"GrandCompany"] = 0
print(len(gc_item_df))
print(gc_item_df["GrandCompany"].value_counts())
gc_item_df["IsTradeable"] = gc_item_df["IsUntradable"] ^ True 

# print(gc_item_df["Item"].value_counts())
gc_item_df = gc_item_df.drop_duplicates(subset=["Name","Item"])
print(len(gc_item_df))
gc_item_df = gc_item_df[["Item","Name","RequiredGCRank","GCSealsCost","StackSize","IsUnique","IsTradeable","GrandCompany"]]
gc_item_df = gc_item_df.dropna()

print(gc_item_df["Item"].value_counts())
gc_item_df = gc_item_df.set_index("Item")
gc_item_df.to_csv("gc_items.csv")
print(gc_item_df.columns)
gc_item_df.to_json("gc_items.json", orient='index')
print("Done")
# Out:
# Index(['#', 'Item', 'Required{GrandCompanyRank}', 'Cost{GCSeals}', 'SortKey',
#        'Name', 'StackSize', 'IsUnique', 'IsUntradable'],
#       dtype='object')
# 911
# 3    305
# 1    303
# 2    303
# Name: GrandCompany, dtype: int64
# 911
# 0    408
# 3    169
# 1    167
# 2    167
# Name: GrandCompany, dtype: int64
# 622
# 5594    1
# 9192    1
# 1692    1
# 1762    1
# 1831    1
#        ..
# 7528    1
# 7529    1
# 7530    1
# 7531    1
# 9357    1
# Name: Item, Length: 621, dtype: int64
# Index(['Name', 'RequiredGCRank', 'GCSealsCost', 'StackSize', 'IsUnique',
#        'IsTradeable', 'GrandCompany'],
#       dtype='object')
# Done

# %%
gcs[gcs.isna().any(axis=1)]
# Out:
#          #  Item  RequiredGCRank  GCSealsCost  SortKey Name  StackSize  \
# 15    1.15     0               0            0        0  NaN          1
# 37    2.21     0               0            0        0  NaN          1
# 65    3.27     0               0            0        0  NaN          1
# 86    4.20     0               0            0        0  NaN          1
# 87    4.21     0               0            0        0  NaN          1
# 88    4.22     0               0            0        0  NaN          1
# 89    4.23     0               0            0        0  NaN          1
# 90    4.24     0               0            0        0  NaN          1
# 91    4.25     0               0            0        0  NaN          1
# 92    4.26     0               0            0        0  NaN          1
# 131   5.38     0               0            0        0  NaN          1
# 162   6.30     0               0            0        0  NaN          1
# 202   7.39     0               0            0        0  NaN          1
# 242   8.39     0               0            0        0  NaN          1
# 255   9.12     0               0            0        0  NaN          1
# 271  10.15     0               0            0        0  NaN          1
# 293  11.21     0               0            0        0  NaN          1
# 321  12.27     0               0            0        0  NaN          1
# 342  13.20     0               0            0        0  NaN          1
# 343  13.21     0               0            0        0  NaN          1
# 344  13.22     0               0            0        0  NaN          1
# 345  13.23     0               0            0        0  NaN          1
# 346  13.24     0               0            0        0  NaN          1
# 347  13.25     0               0            0        0  NaN          1
# 348  13.26     0               0            0        0  NaN          1
# 386  14.37     0               0            0        0  NaN          1
# 418  15.31     0               0            0        0  NaN          1
# 458  16.39     0               0            0        0  NaN          1
# 498  17.39     0               0            0        0  NaN          1
# 511  18.12     0               0            0        0  NaN          1
# 527  19.15     0               0            0        0  NaN          1
# 549  20.21     0               0            0        0  NaN          1
# 578  21.28     0               0            0        0  NaN          1
# 599  22.20     0               0            0        0  NaN          1
# 600  22.21     0               0            0        0  NaN          1
# 601  22.22     0               0            0        0  NaN          1
# 602  22.23     0               0            0        0  NaN          1
# 603  22.24     0               0            0        0  NaN          1
# 604  22.25     0               0            0        0  NaN          1
# 605  22.26     0               0            0        0  NaN          1
# 643  23.37     0               0            0        0  NaN          1
# 675  24.31     0               0            0        0  NaN          1
# 716  25.40     0               0            0        0  NaN          1
# 756  26.39     0               0            0        0  NaN          1
# 769  27.12     0               0            0        0  NaN          1
# 773  28.30     0               0            0        0  NaN          1
# 774  29.00     0               0            0        0  NaN          1
# 816  30.41     0               0            0        0  NaN          1
# 820  31.30     0               0            0        0  NaN          1
# 821  32.00     0               0            0        0  NaN          1
# 863  33.41     0               0            0        0  NaN          1
# 867  34.30     0               0            0        0  NaN          1
# 868  35.00     0               0            0        0  NaN          1
# 910  36.41     0               0            0        0  NaN          1
#
#      IsUnique  IsUntradable
# 15      False         False
# 37      False         False
# 65      False         False
# 86      False         False
# 87      False         False
# 88      False         False
# 89      False         False
# 90      False         False
# 91      False         False
# 92      False         False
# 131     False         False
# 162     False         False
# 202     False         False
# 242     False         False
# 255     False         False
# 271     False         False
# 293     False         False
# 321     False         False
# 342     False         False
# 343     False         False
# 344     False         False
# 345     False         False
# 346     False         False
# 347     False         False
# 348     False         False
# 386     False         False
# 418     False         False
# 458     False         False
# 498     False         False
# 511     False         False
# 527     False         False
# 549     False         False
# 578     False         False
# 599     False         False
# 600     False         False
# 601     False         False
# 602     False         False
# 603     False         False
# 604     False         False
# 605     False         False
# 643     False         False
# 675     False         False
# 716     False         False
# 756     False         False
# 769     False         False
# 773     False         False
# 774     False         False
# 816     False         False
# 820     False         False
# 821     False         False
# 863     False         False
# 867     False         False
# 868     False         False
# 910     False         False

# %%
# gcs["Name"] = gcs["Item"].map(df.set_index("#")["Name"])

# %%
# gcs["IsUntradable"] = gcs["Item"].map(df.set_index("#")["IsUntradable"])

# %%
# gcs[gcs["IsUntradable"]==False]
# Out:
#          #   Item  Required{GrandCompanyRank}  Cost{GCSeals}  SortKey  \
# 0     1.00   5594                           1             12       50
# 1     1.10   5595                           1             34       50
# 2     1.20   5596                           1             70       50
# 3     1.30   4564                           1            120       50
# 4     1.40   4566                           1            290       50
# ..     ...    ...                         ...            ...      ...
# 897  36.28   9372                           9            250       20
# 907  36.38   9356                           9           2300       15
# 908  36.39  15649                           9           7000       15
# 909  36.40   9357                          11           2500       60
# 910  36.41      0                           0              0        0
#
#                         Name  IsUntradable
# 0        Grade 1 Dark Matter         False
# 1        Grade 2 Dark Matter         False
# 2        Grade 3 Dark Matter         False
# 3                   Antidote         False
# 4                 Echo Drops         False
# ..                       ...           ...
# 897     Roasted Coffee Beans         False
# 907  Quick-hardening Sealant         False
# 908              Glass Fiber         False
# 909   Xelphatol Spring Water         False
# 910                      NaN         False
#
# [295 rows x 7 columns]

# %%
# df[df["#"] in list(gcs["Item"])]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 df[df["#"] in list(gcs["Item"])]
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
import pandas as pd

item_df = pd.read_csv("Item.csv",skiprows=[0,2])
gc_item_df = pd.read_csv("GCScripShopItem.csv", skiprows=[0,2,3])

def maplink(df1,df2,keys):
    for key in keys:
        df1[key] = gcs["Item"].map(df.set_index("#")[key])

maplink(gc_item_df,item_df, ["Name", 'StackSize', 'IsUnique', 'IsUntradable'])

gc_item_df=gc_item_df.rename(columns={gc_item_df.columns[2]:"RequiredGCRank","Cost{GCSeals}":"GCSealsCost"})

gc_item_df["IsTradeable"] = gc_item_df["IsUntradable"] ^ True 
gc_item_df = gc_item_df[["Item","Name","RequiredGCRank","GCSealsCost","StackSize","IsUnique","IsTradeable"]].dropna()
gc_item_df = gc_item_df.drop_duplicates()
gc_item_df=gc_item_df.set_index("Item")
gc_item_df.to_csv("gc_items.csv")
gc_item_df.to_json("gc_items.json", orient='index')

# %%
gc_item_df["Item"].value_counts()
# Out:
# 5594     3
# 7526     3
# 21319    3
# 21320    3
# 22498    3
#         ..
# 4436     1
# 3813     1
# 3811     1
# 3812     1
# 10546    1
# Name: Item, Length: 621, dtype: int64

# %%
gc_item_df[gc_item_df["Item"]==5594]
# Out:
#      Item                 Name  RequiredGCRank  GCSealsCost  StackSize  \
# 0    5594  Grade 1 Dark Matter               1           12        999
# 256  5594  Grade 1 Dark Matter               1           12        999
# 512  5594  Grade 1 Dark Matter               1           12        999
#
#      IsUnique  IsTradeable
# 0       False         True
# 256     False         True
# 512     False         True

# %%
from univ_tools import univ_client

# from univ_tools import univ_client
from xivjson import gc_ranks, servers_lookup, reverse_servers_lookup, gc_items
def get_univ_client():
    return univ_client()
univ_client = get_univ_client()

# %%
def cache_tradeables():
    import pandas as pd
    # df = pd.read_json(gc_items)
    # return df[df["IsTradeable"]]
    df = pd.DataFrame.from_dict(gc_items, orient='index')
    return df[df["IsTradeable"]]
tradeable_gc_items = cache_tradeables()

# %%
params = {
        'listings': 10,
        'entries': 30,
        'statsWithin': 1,
        # 'entriesWithin': 5*24*60*60*1000
        }
l = "".join([x+", " for x in tradeable_gc_items.index.to_list()])[:-2]

# %%
out = univ_client.raw_price_query(l, region="Faerie", params=params)

# %%
out.keys()
# Out:
# dict_keys(['itemIDs', 'items', 'worldID', 'unresolvedItems', 'worldName'])

# %%
out["unresolvedItems"] in out["itemIDs"] #ventures are tradeable? lmaooo
# Out:
# False

# %%
for x in out["items"][str(out["itemIDs"][0])].keys():
    print(x)
# Out:
# itemID
# worldID
# lastUploadTime
# listings
# recentHistory
# currentAveragePrice
# currentAveragePriceNQ
# currentAveragePriceHQ
# regularSaleVelocity
# nqSaleVelocity
# hqSaleVelocity
# averagePrice
# averagePriceNQ
# averagePriceHQ
# minPrice
# minPriceNQ
# minPriceHQ
# maxPrice
# maxPriceNQ
# maxPriceHQ
# stackSizeHistogram
# stackSizeHistogramNQ
# stackSizeHistogramHQ
# worldName
# listingsCount
# recentHistoryCount
# unitsForSale
# unitsSold

# %%
out["items"][str(out["itemIDs"][0])]
# Out:
# {'itemID': 5594,
#  'worldID': 54,
#  'lastUploadTime': 1726339738467,
#  'listings': [{'lastReviewTime': 1726339738,
#    'pricePerUnit': 1,
#    'quantity': 13,
#    'stainID': 0,
#    'creatorName': '',
#    'creatorID': None,
#    'hq': False,
#    'isCrafted': False,
#    'listingID': '3799912908330807',
#    'materia': [],
#    'onMannequin': False,
#    'retainerCity': 4,
#    'retainerID': '33777097242916980',
#    'retainerName': 'Usagiska',
#    'sellerID': None,
#    'total': 13,
#    'tax': 0},
#   {'lastReviewTime': 1726339738,
#    'pricePerUnit': 3,
#    'quantity': 13,
#    'stainID': 0,
#    'creatorName': '',
#    'creatorID': None,
#    'hq': False,
#    'isCrafted': False,
#    'listingID': '3799912591247143',
#    'materia': [],
#    'onMannequin': False,
#    'retainerCity': 3,
#    'retainerID': '33777097240879716',
#    'retainerName': 'Pototo-tato',
#    'sellerID': None,
#    'total': 39,
#    'tax': 1},
#   {'lastReviewTime': 1726339738,
#    'pricePerUnit': 3,
#    'quantity': 33,
#    'stainID': 0,
#    'creatorName': '',
#    'creatorID': None,
#    'hq': False,
#    'isCrafted': False,
#    'listingID': '3799912890670993',
#    'materia': [],
#    'onMannequin': False,
#    'retainerCity': 1,
#    'retainerID': '33777097242896148',
#    'retainerName': 'Chahlie',
#    'sellerID': None,
#    'total': 99,
#    'tax': 4},
#   {'lastReviewTime': 1726339738,
#    'pricePerUnit': 10,
#    'quantity': 13,
#    'stainID': 0,
#    'creatorName': '',
#    'creatorID': None,
#    'hq': False,
#    'isCrafted': False,
#    'listingID': '3799912455767598',
#    'materia': [],
#    'onMannequin': False,
#    'retainerCity': 3,
#    'retainerID': '33777097238954411',
#    'retainerName': 'Arivelle',
#    'sellerID': None,
#    'total': 130,
#    'tax': 6},
#   {'lastReviewTime': 1726339738,
#    'pricePerUnit': 21,
#    'quantity': 45,
#    'stainID': 0,
#    'creatorName': '',
#    'creatorID': None,
#    'hq': False,
#    'isCrafted': False,
#    'listingID': '3799912856151626',
#    'materia': [],
#    'onMannequin': False,
#    'retainerCity': 4,
#    'retainerID': '33777097242399135',
#    'retainerName': 'Jakefox',
#    'sellerID': None,
#    'total': 945,
#    'tax': 47},
#   {'lastReviewTime': 1726339738,
#    'pricePerUnit': 21,
#    'quantity': 90,
#    'stainID': 0,
#    'creatorName': '',
#    'creatorID': None,
#    'hq': False,
#    'isCrafted': False,
#    'listingID': '3799912913647523',
#    'materia': [],
#    'onMannequin': False,
#    'retainerCity': 3,
#    'retainerID': '33777097242496737',
#    'retainerName': 'Tygu',
#    'sellerID': None,
#    'total': 1890,
#    'tax': 94},
#   {'lastReviewTime': 1726339738,
#    'pricePerUnit': 21,
#    'quantity': 99,
#    'stainID': 0,
#    'creatorName': '',
#    'creatorID': None,
#    'hq': False,
#    'isCrafted': False,
#    'listingID': '3799912950917365',
#    'materia': [],
#    'onMannequin': False,
#    'retainerCity': 4,
#    'retainerID': '33777097242399135',
#    'retainerName': 'Jakefox',
#    'sellerID': None,
#    'total': 2079,
#    'tax': 103},
#   {'lastReviewTime': 1726339738,
#    'pricePerUnit': 40,
#    'quantity': 20,
#    'stainID': 0,
#    'creatorName': '',
#    'creatorID': None,
#    'hq': False,
#    'isCrafted': False,
#    'listingID': '3799912947269418',
#    'materia': [],
#    'onMannequin': False,
#    'retainerCity': 1,
#    'retainerID': '33777097242640082',
#    'retainerName': 'Luna-nene',
#    'sellerID': None,
#    'total': 800,
#    'tax': 40},
#   {'lastReviewTime': 1726339738,
#    'pricePerUnit': 50,
#    'quantity': 3,
#    'stainID': 0,
#    'creatorName': '',
#    'creatorID': None,
#    'hq': False,
#    'isCrafted': False,
#    'listingID': '3799912908438304',
#    'materia': [],
#    'onMannequin': False,
#    'retainerCity': 1,
#    'retainerID': '33777097242820503',
#    'retainerName': 'Weweqae',
#    'sellerID': None,
#    'total': 150,
#    'tax': 7},
#   {'lastReviewTime': 1726339738,
#    'pricePerUnit': 55,
#    'quantity': 3,
#    'stainID': 0,
#    'creatorName': '',
#    'creatorID': None,
#    'hq': False,
#    'isCrafted': False,
#    'listingID': '3799912912179647',
#    'materia': [],
#    'onMannequin': False,
#    'retainerCity': 3,
#    'retainerID': '33777097242881510',
#    'retainerName': 'Aardvarkseller',
#    'sellerID': None,
#    'total': 165,
#    'tax': 8}],
#  'recentHistory': [{'hq': False,
#    'pricePerUnit': 45,
#    'quantity': 3,
#    'timestamp': 1726043149,
#    'onMannequin': False,
#    'buyerName': 'Dr Frost',
#    'total': 135},
#   {'hq': False,
#    'pricePerUnit': 20,
#    'quantity': 10,
#    'timestamp': 1726026831,
#    'onMannequin': False,
#    'buyerName': 'Sarin Megistus',
#    'total': 200},
#   {'hq': False,
#    'pricePerUnit': 20,
#    'quantity': 53,
#    'timestamp': 1725926239,
#    'onMannequin': False,
#    'buyerName': 'Sicard Spence',
#    'total': 1060},
#   {'hq': False,
#    'pricePerUnit': 1,
#    'quantity': 10,
#    'timestamp': 1725913419,
#    'onMannequin': False,
#    'buyerName': 'Noel Lockhart',
#    'total': 10},
#   {'hq': False,
#    'pricePerUnit': 1,
#    'quantity': 13,
#    'timestamp': 1725878059,
#    'onMannequin': False,
#    'buyerName': 'Leeva Lee',
#    'total': 13},
#   {'hq': False,
#    'pricePerUnit': 20,
#    'quantity': 23,
#    'timestamp': 1725552512,
#    'onMannequin': False,
#    'buyerName': 'Jay Hoshi',
#    'total': 460},
#   {'hq': False,
#    'pricePerUnit': 61,
#    'quantity': 99,
#    'timestamp': 1725521704,
#    'onMannequin': False,
#    'buyerName': 'Doomy Dino',
#    'total': 6039},
#   {'hq': False,
#    'pricePerUnit': 1,
#    'quantity': 13,
#    'timestamp': 1725463267,
#    'onMannequin': False,
#    'buyerName': 'Izzy Lefonte',
#    'total': 13},
#   {'hq': False,
#    'pricePerUnit': 49,
#    'quantity': 3,
#    'timestamp': 1724691134,
#    'onMannequin': False,
#    'buyerName': 'Peach Milk',
#    'total': 147},
#   {'hq': False,
#    'pricePerUnit': 50,
#    'quantity': 13,
#    'timestamp': 1724621184,
#    'onMannequin': False,
#    'buyerName': 'Primo Lion',
#    'total': 650},
#   {'hq': False,
#    'pricePerUnit': 31,
#    'quantity': 10,
#    'timestamp': 1724621155,
#    'onMannequin': False,
#    'buyerName': 'Primo Lion',
#    'total': 310},
#   {'hq': False,
#    'pricePerUnit': 10,
#    'quantity': 63,
#    'timestamp': 1724366618,
#    'onMannequin': False,
#    'buyerName': 'Mistress Seika',
#    'total': 630},
#   {'hq': False,
#    'pricePerUnit': 20,
#    'quantity': 3,
#    'timestamp': 1724141388,
#    'onMannequin': False,
#    'buyerName': 'Syrenead Yapa',
#    'total': 60},
#   {'hq': False,
#    'pricePerUnit': 15,
#    'quantity': 23,
#    'timestamp': 1724141383,
#    'onMannequin': False,
#    'buyerName': 'Syrenead Yapa',
#    'total': 345},
#   {'hq': False,
#    'pricePerUnit': 11,
#    'quantity': 10,
#    'timestamp': 1724141380,
#    'onMannequin': False,
#    'buyerName': 'Syrenead Yapa',
#    'total': 110},
#   {'hq': False,
#    'pricePerUnit': 11,
#    'quantity': 10,
#    'timestamp': 1724141377,
#    'onMannequin': False,
#    'buyerName': 'Syrenead Yapa',
#    'total': 110},
#   {'hq': False,
#    'pricePerUnit': 9,
#    'quantity': 3,
#    'timestamp': 1724141375,
#    'onMannequin': False,
#    'buyerName': 'Syrenead Yapa',
#    'total': 27},
#   {'hq': False,
#    'pricePerUnit': 8,
#    'quantity': 3,
#    'timestamp': 1724141373,
#    'onMannequin': False,
#    'buyerName': 'Syrenead Yapa',
#    'total': 24},
#   {'hq': False,
#    'pricePerUnit': 8,
#    'quantity': 13,
#    'timestamp': 1724141372,
#    'onMannequin': False,
#    'buyerName': 'Syrenead Yapa',
#    'total': 104},
#   {'hq': False,
#    'pricePerUnit': 1,
#    'quantity': 13,
#    'timestamp': 1724141370,
#    'onMannequin': False,
#    'buyerName': 'Syrenead Yapa',
#    'total': 13},
#   {'hq': False,
#    'pricePerUnit': 1,
#    'quantity': 3,
#    'timestamp': 1724107393,
#    'onMannequin': False,
#    'buyerName': 'Syrenead Yapa',
#    'total': 3},
#   {'hq': False,
#    'pricePerUnit': 1,
#    'quantity': 20,
#    'timestamp': 1724107390,
#    'onMannequin': False,
#    'buyerName': 'Syrenead Yapa',
#    'total': 20},
#   {'hq': False,
#    'pricePerUnit': 100,
#    'quantity': 99,
#    'timestamp': 1723866705,
#    'onMannequin': False,
#    'buyerName': 'Fuji Yokimoni',
#    'total': 9900},
#   {'hq': False,
#    'pricePerUnit': 1,
#    'quantity': 13,
#    'timestamp': 1723823253,
#    'onMannequin': False,
#    'buyerName': 'Alea Akras',
#    'total': 13},
#   {'hq': False,
#    'pricePerUnit': 10,
#    'quantity': 10,
#    'timestamp': 1722873955,
#    'onMannequin': False,
#    'buyerName': 'Lune Violette',
#    'total': 100},
#   {'hq': False,
#    'pricePerUnit': 20,
#    'quantity': 3,
#    'timestamp': 1722800263,
#    'onMannequin': False,
#    'buyerName': "S'paroh Pond",
#    'total': 60},
#   {'hq': False,
#    'pricePerUnit': 11,
#    'quantity': 13,
#    'timestamp': 1722800261,
#    'onMannequin': False,
#    'buyerName': "S'paroh Pond",
#    'total': 143},
#   {'hq': False,
#    'pricePerUnit': 11,
#    'quantity': 13,
#    'timestamp': 1722800260,
#    'onMannequin': False,
#    'buyerName': "S'paroh Pond",
#    'total': 143},
#   {'hq': False,
#    'pricePerUnit': 5,
#    'quantity': 4,
#    'timestamp': 1722800259,
#    'onMannequin': False,
#    'buyerName': "S'paroh Pond",
#    'total': 20},
#   {'hq': False,
#    'pricePerUnit': 1,
#    'quantity': 3,
#    'timestamp': 1722800257,
#    'onMannequin': False,
#    'buyerName': "S'paroh Pond",
#    'total': 3}],
#  'currentAveragePrice': 22.5,
#  'currentAveragePriceNQ': 22.5,
#  'currentAveragePriceHQ': 0,
#  'regularSaleVelocity': 0,
#  'nqSaleVelocity': 0,
#  'hqSaleVelocity': 0,
#  'averagePrice': 18.433332,
#  'averagePriceNQ': 18.433332,
#  'averagePriceHQ': 0,
#  'minPrice': 1,
#  'minPriceNQ': 1,
#  'minPriceHQ': 0,
#  'maxPrice': 55,
#  'maxPriceNQ': 55,
#  'maxPriceHQ': 0,
#  'stackSizeHistogram': {'3': 2,
#   '13': 3,
#   '20': 1,
#   '33': 1,
#   '45': 1,
#   '90': 1,
#   '99': 1},
#  'stackSizeHistogramNQ': {'3': 2,
#   '13': 3,
#   '20': 1,
#   '33': 1,
#   '45': 1,
#   '90': 1,
#   '99': 1},
#  'stackSizeHistogramHQ': {},
#  'worldName': 'Faerie',
#  'listingsCount': 10,
#  'recentHistoryCount': 30,
#  'unitsForSale': 332,
#  'unitsSold': 572}

# %%
_=[print(x) for x in out["items"][str(out["itemIDs"][0])]["listings"][0].items()]
# Out:
# ('lastReviewTime', 1726339738)
# ('pricePerUnit', 1)
# ('quantity', 13)
# ('stainID', 0)
# ('creatorName', '')
# ('creatorID', None)
# ('hq', False)
# ('isCrafted', False)
# ('listingID', '3799912908330807')
# ('materia', [])
# ('onMannequin', False)
# ('retainerCity', 4)
# ('retainerID', '33777097242916980')
# ('retainerName', 'Usagiska')
# ('sellerID', None)
# ('total', 13)
# ('tax', 0)

# %%
def process_listings(listings, window=7*24*60*60):
    lowest_price = None
    listings_updated = 0
    unique_retainers = {}
    t = int(time.time())
    for x in listings:
        if x["onMannequin"]:
            continue
        if t-x["lastReviewTime"] > window:
            continue
        if lowest_price is None or x["pricePerUnit"] < lowest_price:
            lowest_price = x["pricePerUnit"]
        listings_updated += 1
        unique_retainers[x["retainerID"]]=True

    return lowest_price, listings_updated, len(unique_retainers.keys())

process_listings(out["items"][str(out["itemIDs"][0])]["listings"])
# Out:
# (1, 10, 9)

# %%
_=[print(x) for x in out["items"][str(out["itemIDs"][0])]["recentHistory"][0].items()]
# Out:
# ('hq', False)
# ('pricePerUnit', 45)
# ('quantity', 3)
# ('timestamp', 1726043149)
# ('onMannequin', False)
# ('buyerName', 'Dr Frost')
# ('total', 135)

# %%
import time
int(time.time())-1726043149
# Out:
# 615297

# %%
def process_sales(sales, window=7*24*60*60, max_count=None):
    #"Avg price per", "Listings sold", "Items Sold", "Unique Buyers",
    pass
    #filter mannequins, launderers
    t = time.time()
    listings_sold = 0
    items_sold = 0
    avg_price = [] #per listing, not per item in stack
    unique_buyers = {}
    for x in sales:
        if x["onMannequin"]:
            continue
        if int(t)-x["timestamp"] > window:
            # print(int(t)-x["timestamp"],window)
            continue
        unique_buyers[x['buyerName']] = True
        avg_price += x['pricePerUnit']
        items_sold += x["quantity"]
        listings_sold += 1

    avg = sum(avg_price)/len(avg_price) if len(avg_price)!= 0 else -1 

    return listings_sold, items_sold, avg, len(unique_buyers.keys())

process_sales(out["items"][str(out["itemIDs"][0])]["recentHistory"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [184], in <cell line: 25>()
#      21     avg = sum(avg_price)/len(avg_price) if len(avg_price)!= 0 else -1
#      23     return listings_sold, items_sold, avg, len(unique_buyers.keys())
# ---> 25 _ = [print(process_sales(x)) for x in out["items"][str(out["itemIDs"][0])]["recentHistory"]]
#
# Input In [184], in <listcomp>(.0)
#      21     avg = sum(avg_price)/len(avg_price) if len(avg_price)!= 0 else -1
#      23     return listings_sold, items_sold, avg, len(unique_buyers.keys())
# ---> 25 _ = [print(process_sales(x)) for x in out["items"][str(out["itemIDs"][0])]["recentHistory"]]
#
# Input In [184], in process_sales(sales, window, max_count)
#       9 unique_buyers = {}
#      10 for x in sales:
# ---> 11     if x["onMannequin"]:
#      12         continue
#      13     if int(t)-x["timestamp"] > window:
#      14         # print(int(t)-x["timestamp"],window)
#
# TypeError: string indices must be integers
